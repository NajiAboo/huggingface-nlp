# %% [markdown]
# ## **Zero shot classification**
#
# Zero shot text classification is a tak in natural language processing where a model is trained on a set of labelled examples but is then able to classify new examples from previously unseen classes

# %% [markdown]
# ## **Supervised Learning**
#
#
# *   Train the model with X features and Y Label / Classes
# *   Inference - Model predict the correct Labels / Classes
# *   Requires large amount of labelled data
# *   Getting data is difficult

# %% [markdown]
# ## **How Human do Zero Shot Learing?**
#
#
# *   First time sees Zebra

# %% [markdown]
# ## **Zero Shot Text Classifier ( ZSTC )**
#
#
# *   Dont need a huge amount of labelled data
# *   Relies on
#      * availability of labelled data
#      * unseen classes and seen classess - semantic relation

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 45.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 22.9 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
classifer = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
classifer("This is a course about Transformer library", candidate_labels=["education","politics","business","learning","study"])
# Out:
# {'sequence': 'This is a course about Transformer library',
#  'labels': ['learning', 'study', 'education', 'business', 'politics'],
#  'scores': [0.4973551034927368,
#   0.3025500476360321,
#   0.1892959028482437,
#   0.007841763086616993,
#   0.002957169432193041]}
